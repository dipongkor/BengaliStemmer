# %%
from bn_rule_based_stemmer import *

# %%
sentence = "চট্টগ্রাম বিশ্ববিদ্যালয়ে ছাত্রলীগের অভ্যন্তরীণ বিরোধের জের ধরে ত্রিপক্ষীয় সংঘর্ষে দুই হলের ৮০টিরও বেশি কক্ষ ভাঙচুরের ঘটনা ঘটেছে বুধবার গভীর রাতে টানা দু ঘণ্টা ধরে চলা এ সংঘর্ষে পক্ষে-বিপক্ষের ৪৩ নেতা-কর্মী আহত হয়েছে পরে পুলিশ এসে পরিস্থিতি নিয়ন্ত্রণ করে এ ঘটনায় হল দুটি থেকে ৫৯ জনকে পুলিশ আটক করলেও শেষ পর্যন্ত ৭ জনকে হাটহাজারী থানায় নিয়ে গেছে সেখানে তাদের আটক দেখানো হয়েছে এদিকে সংঘর্ষ থামলেও  আজ বৃহস্পতিবারও (৫ মার্চ) ক্যাম্পাসে উভয়পক্ষের মধ্যে এখনও চাপা উত্তেজনা বিরাজ করছে হলের সাধারণ শিক্ষার্থীরা প্রচণ্ড আতঙ্কের মধ্যে রয়েছেন বিবদমান পক্ষগুলোকে নিয়ে সমাধানের জন্য রাতেই বৈঠকে বসছেন উপাচার্য অধ্যাপক ড. শিরীণ আখতার"
words = sentence.split(" ")
result = {}
stemmer = BengaliStemmer()
for word in words:
    root = stemmer.findStem(word)
    result[word] = root

# %%
result
# Out:
# {'চট্টগ্রাম': 'চট্টগ্রাম',
#  'বিশ্ববিদ্যালয়ে': 'বিশ্ববিদ্যালয়',
#  'ছাত্রলীগের': 'ছাত্রলীগ',
#  'অভ্যন্তরীণ': 'অভ্যন্তরীণ',
#  'বিরোধের': 'বিরোধ',
#  'জের': 'জ',
#  'ধরে': 'ধর',
#  'ত্রিপক্ষীয়': 'ত্রিপক্ষী',
#  'সংঘর্ষে': 'সংঘর্ষ',
#  'দুই': 'দ',
#  'হলের': 'হল',
#  '৮০টিরও': '৮০টিরও',
#  'বেশি': 'বেশ',
#  'কক্ষ': 'কক্ষ',
#  'ভাঙচুরের': 'ভাঙচুর',
#  'ঘটনা': 'ঘটন',
#  'ঘটেছে': 'ঘটেছ',
#  'বুধবার': 'বুধবা',
#  'গভীর': 'গভী',
#  'রাতে': '',
#  'টানা': 'টান',
#  'দু': 'দু',
#  'ঘণ্টা': 'ঘণ্',
#  'চলা': 'চল',
#  'এ': 'এ',
#  'পক্ষে-বিপক্ষের': 'পক্ষে-বিপক্ষ',
#  '৪৩': '৪৩',
#  'নেতা-কর্মী': 'নেতা-কর্মী',
#  'আহত': 'আহ',
#  'হয়েছে': 'হয়েছ',
#  'পরে': 'পর',
#  'পুলিশ': 'পুলিশ',
#  'এসে': 'এস',
#  'পরিস্থিতি': 'পরিস্থিতি',
#  'নিয়ন্ত্রণ': 'নিয়ন্ত্রণ',
#  'করে': 'কর',
#  'ঘটনায়': 'ঘটনা',
#  'হল': 'হল',
#  'দুটি': 'দু',
#  'থেকে': 'থ',
#  '৫৯': '৫৯',
#  'জনকে': '',
#  'আটক': 'আট',
#  'করলেও': 'করলে',
#  'শেষ': 'শেষ',
#  'পর্যন্ত': 'পর্যন্ত',
#  '৭': '৭',
#  'হাটহাজারী': 'হাটহাজারী',
# ...

# %%
s2 = "মোদির বাংলাদেশ সফর নিশ্চিত করল ভারতের পররাষ্ট্র মন্ত্রণালয়"
for word in s2.split(" "):
    print(f"{word}: {stemmer.findStem(word)}")
# Out:
# মোদির: মোদি
# বাংলাদেশ: বাংলাদেশ
# সফর: সফ
# নিশ্চিত: নিশ্চিত
# করল: কর
# ভারতের: ভারত
# পররাষ্ট্র: পররাষ্ট্
# মন্ত্রণালয়: মন্ত্রণাল
